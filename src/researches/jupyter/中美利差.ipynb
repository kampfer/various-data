# %%
import akshare as ak
import pandas as pd
import matplotlib.pyplot as plt

# %%
usAndChinaBondYieldDf = ak.bond_zh_us_rate()
usAndChinaBondYieldDf.tail()
# Out:
#               日期  中国国债收益率2年  中国国债收益率5年  中国国债收益率10年  中国国债收益率30年  中国国债收益率10年-2年  \
# 8360  2023-01-11     2.3709     2.6989      2.8603      3.2331         0.4894
# 8361  2023-01-12     2.3677     2.6974      2.8778      3.2378         0.5101
# 8362  2023-01-13     2.3790     2.7096      2.9010      3.2476         0.5220
# 8363  2023-01-16     2.4164     2.7571      2.9167      3.2677         0.5003
# 8364  2023-01-17     2.4013     2.7346      2.9017      3.2531         0.5004
#
#       中国GDP年增率  美国国债收益率2年  美国国债收益率5年  美国国债收益率10年  美国国债收益率30年  美国国债收益率10年-2年  \
# 8360       NaN       4.20       3.66        3.54        3.67          -0.66
# 8361       NaN       4.12       3.53        3.43        3.56          -0.69
# 8362       NaN       4.22       3.60        3.49        3.61          -0.73
# 8363       NaN        NaN        NaN         NaN         NaN            NaN
# 8364       NaN       4.18       3.60        3.53        3.64          -0.65
#
#       美国GDP年增率
# 8360       NaN
# 8361       NaN
# 8362       NaN
# 8363       NaN
# 8364       NaN

# %%
chinaBondYieldDf = ak.bond_china_yield()
chinaBondYieldDf
# Out:
#                     曲线名称          日期      3月      6月      1年      3年      5年  \
# 0      中债中短期票据收益率曲线(AAA)  2020-02-04  2.8939  2.8998  2.9158  3.1970  3.4503
# 1    中债商业银行普通债收益率曲线(AAA)  2020-02-04  2.7215  2.7370  2.8042  2.9979  3.3120
# 2              中债国债收益率曲线  2020-02-04  1.7475  1.7630  2.1000  2.4056  2.6399
# 3              中债国债收益率曲线  2020-02-05  1.7475  1.7667  2.0773  2.4264  2.6348
# 4      中债中短期票据收益率曲线(AAA)  2020-02-05  2.7991  2.8975  2.9118  3.1949  3.4609
# ..                   ...         ...     ...     ...     ...     ...     ...
# 733  中债商业银行普通债收益率曲线(AAA)  2021-01-21  2.5253  2.6560  2.8619  3.3327  3.5486
# 734            中债国债收益率曲线  2021-01-21  2.0318  2.1555  2.4475  2.7600  2.9244
# 735    中债中短期票据收益率曲线(AAA)  2021-01-22  2.6080  2.7656  2.9490  3.5403  3.7004
# 736  中债商业银行普通债收益率曲线(AAA)  2021-01-22  2.5210  2.6557  2.8580  3.3284  3.5453
# 737            中债国债收益率曲线  2021-01-22  2.0316  2.1355  2.4525  2.7645  2.9373
#
#          7年     10年     30年
# 0    3.7153  3.9597     NaN
# 1    3.5849  3.8158  4.2435
# 2    2.7906  2.8551  3.4488
# 3    2.7893  2.8440  3.4460
# 4    3.7157  3.9601     NaN
# ..      ...     ...     ...
# 733  3.7171  3.8553  4.4712
# 734  3.1216  3.1335  3.7198
# 735  3.8979  4.0566     NaN
# 736  3.6985  3.8367  4.4626
# 737  3.1112  3.1185  3.7156
#
# [738 rows x 10 columns]

# %%
usAndChina10YearBondYieldDf = pd.DataFrame(
    {
        '中国国债收益率10年': usAndChinaBondYieldDf['中国国债收益率10年'],
        '美国国债收益率10年': usAndChinaBondYieldDf['美国国债收益率10年']
    },
#     index=usAndChinaBondYieldDf['日期']
)
usAndChina10YearBondYieldDf.index = usAndChinaBondYieldDf['日期']

# %%
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False #用来正常显示负号

usAndChina10YearBondYieldDf.plot()
# Out:
# <AxesSubplot: xlabel='日期'>
